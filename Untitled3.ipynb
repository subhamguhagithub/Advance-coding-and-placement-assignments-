# %% [markdown]
# <a href="https://colab.research.google.com/github/subhamguhagithub/Advance-coding-and-placement-assignments-/blob/main/Untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
class Student:

    """Docstring of the class"""

    def __init__(self):   # compulsory constructor
        self.name = "Anurag"     # instance variable
        self.roll_no = 101

# object creation
s1 = Student()

# printing values
print(s1.name)
print(s1.roll_no)
# Out:
# Anurag
# 101
